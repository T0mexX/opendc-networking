# %%
import pandas as pd

# %%
pd.read_parquet("net-test.parquet")
# Out:
#                     a_timestamp  b_num_flows  c_num_nodes  d_num_host_nodes  \
# 0     2013-08-12 13:40:46+00:00           73          209               128
# 1     2013-08-12 13:45:46+00:00           73          209               128
# 2     2013-08-12 13:50:46+00:00           75          209               128
# 3     2013-08-12 13:55:46+00:00           81          209               128
# 4     2013-08-12 14:00:46+00:00           78          209               128
# ...                         ...          ...          ...               ...
# 28303 2013-09-11 13:36:15+00:00           77          209               128
# 28304 2013-09-11 13:37:20+00:00           77          209               128
# 28305 2013-09-11 13:38:12+00:00           77          209               128
# 28306 2013-09-11 13:38:41+00:00           77          209               128
# 28307 2013-09-11 13:39:58+00:00           82          209               128
#
# ...

# %%
pd.read_parquet("node-test.parquet")
# Out:
#                    b_node_id               a_timestamp c_node_name  \
# 0                          0 2013-08-12 13:40:46+00:00     unknown
# 1                          1 2013-08-12 13:40:46+00:00     unknown
# 2                          2 2013-08-12 13:40:46+00:00     unknown
# 3                          3 2013-08-12 13:40:46+00:00     unknown
# 4                          4 2013-08-12 13:40:46+00:00     unknown
# ...                      ...                       ...         ...
# 5916367                  204 2013-09-11 13:39:58+00:00     unknown
# 5916368                  205 2013-09-11 13:39:58+00:00     unknown
# 5916369                  206 2013-09-11 13:39:58+00:00     unknown
# 5916370                  207 2013-09-11 13:39:58+00:00     unknown
# 5916371 -9223372036854775808 2013-09-11 13:39:58+00:00     unknown
#
#          d_num_incoming_flows  e_num_outgoing_flows  \
# 0                           1                     1
# 1                           0                     0
# ...
